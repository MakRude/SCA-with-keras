# %%
# General modules
import sys
import os
import os.path
from pathlib import Path # creating directories

# math modules
import numpy as np
import tensorflow as tf # used for random seed
## math random seed module
import random as python_random

# load data
from training_modules.load_data import DATA_LOADER
# handling files
from training_modules.handling_saving_stats import get_file_path, save_history, calc_tst_acc, calc_advantage, save_file, display_results
# ## constants for DB_TYPE
from training_modules.misc import TYPE_ASCAD, TYPE_NTRU, TYPE_GAUSS, TYPE_DPA, TYPE_M4SC
# ## constants for handling file types
from training_modules.misc import MODEL_CONST, LOSS_CONST, ACC_CONST, ADV_CONST, TRN_GRPH_CONST, ADV_GRPH_CONST, TST_ACC_CONST, VAL_LOSS_CONST, VAL_ACC_CONST, VAL_ADV_CONST, TST_ADV_CONST
# ## hyper parameters
from hyper_parameters import my_seeds, tot
# training:
from training_modules.train import train_model

# %%
# prepare
models = dict()

# define empty history object
history = dict()

# %%
def read_parameters_from_file(param_filename):
    #read parameters for the train_model and load_traces functions
    #TODO: sanity checks on parameters
    param_file = open(param_filename,"r")

    #TODO: replace eval() by ast.linear_eval()
    my_parameters= eval(param_file.read())

    my_database = my_parameters["database"]
    my_database_title = my_parameters["database_title"]
    return my_database_title, my_database

# %%
#ASCAD: Adapted heavily by Mahmoud Gharra

# NOTE: code could take another database if it has  supported format as the one provided.


# if __name__ == "__main__":

# default parameters values
# # my_database = "../2020_APR_23/polymul32/projects/operand_scanning_32" # Loc on my personal pc
# my_database = "../chipWhisp01/projects/operand_scanning_32" # Loc on Einstein
# DB_title = "operand_scanning_32" # arbitrary name
# DB_TYPE = TYPE_NTRU


# DB_title = my_database = "../schoolbook32/schoolbook32" # loc on Einstein
# # DB_title = "schoolbook32" ## Optional... It's for the graph
# DB_TYPE = TYPE_NTRU


# # my_database = "../2020_MAR_31/ASCAD_data/ASCAD_databases/ASCAD.h5" # Loc on my personal pc
# my_database = "../PRE_MAY_06/ASCAD/ATMEGA_AES_v1/ATM_AES_v1_fixed_key/ASCAD_data/ASCAD_databases/ASCAD.h5" # Loc on Einstein
# DB_title = "ASCAD"
# DB_TYPE = TYPE_ASCAD



# my_database = "../dpa_data"
# DB_title = "DPA contest"
# DB_TYPE = TYPE_DPA


## This is an implementation of schoolbook 32 where the result is aggregated slowly key-wise (for each coeeficient in the key)

my_database = "../../M4SC_1_2020_07_16_155036_8f582681_A.pickle"
DB_title = "M4SC"
DB_TYPE = TYPE_M4SC


# my_database = "../GSprojectNils/projects/GStraces"
# DB_title = "Gaussian Sampler"
# DB_TYPE = TYPE_GAUSS



# TRAINING MODEL IS THE FILE, IN WHICH THE DATA SHOULD BE SAVED
# Network type simply chooses the architecture according to which the data is trained

# 'cnn' works well for operand_scanning_32 with 20 epochs batch 100 and 2 attempts

# CNN training
network_type = "mlp3" ## ATM: you can choose between 'mlp', 'cnn', 'cnn2', and 'cnn3'
# save folder
training_model = "../debugging_file_mlp3_lr1e-2_8bits"
#     training_model = "training_m4sc_lastByte_pol1_mlp_batch100_epochs50_MAXATT1_lr1e-2_valid1e-1"



# create save directory, if it doesn't exist
Path(training_model).mkdir(parents=True, exist_ok=True)
    

accuracies = {}
advantages = {}
### training
print("+ Commense training (takes about 20 seconds per epoch)")
for seed in my_seeds:
    # increasing reproducability of results according to https://keras.io/getting_started/faq/
    # set PYTHONHASHSEED before running program to increase reproducability
    # You can also consider using the CPU, as GPUs are less deterministic. (CUDA="")
    np.random.seed(seed)
    python_random.seed(seed)
#     tf.random.set_random_seed(seed) # older tf versions use this
    tf.random.set_seed(seed)

    data_loader = DATA_LOADER(DB_TYPE, my_database)

    print("++ Data dimestions are: ", np.array(data_loader.X).shape)

    # sample some traces
    # Sampling traces intereferes with the resulting graph. This must mean that I'm doing that suboptimally
    # TODO: fix it, so that saved graph is correct
    print("+ sample {0} traces".format(tot))
    if tot != 0:
        sample_traces(X)
        print("+ print out list of categories:\n {}".format(np.unique(y)))
        print("+ print out shape of labels:\n {}".format(y.shape))

        
    for key_idx in range(data_loader.KEY_LENGTH):
        print('key_idx={}...'.format(key_idx))

        # If it hasn't been trained. Load a model, extract the profiling and attack traces and labels and commense the training
        ## extract profiling and testing data
        data_loader.extract_data(network_type, key_idx=key_idx)
        
        # Check if this seed key combination had been trained in the past
        ## we run individual training for each key integer
        if models.get((seed, key_idx)) is not None:
            ## calculate ACCURACY
            accuracies[(seed, key_idx)] = calc_tst_acc(data_loader, seed=seed, key_idx=key_idx)
            ## calculate ADVANTAGE
            advantages[(seed, key_idx)] = calc_advantage(accuracies.get((seed, key_idx)))
            continue

        _file_path = os.path.normpath(get_file_path(training_model, MODEL_CONST, seed, key_idx))
        if os.path.exists(_file_path) == True:
            models[(seed, key_idx)] = get_file_path(training_model, MODEL_CONST, seed, key_idx)
            ## calculate ACCURACY
            accuracies[(seed, key_idx)] = calc_tst_acc(data_loader, seed=seed, key_idx=key_idx)
            ## calculate ADVANTAGE
            advantages[(seed, key_idx)] = calc_advantage(accuracies.get((seed, key_idx)))
            continue                

        
        ## train model, get number of attempts needed and history struct
        history, att = train_model(data_loader, training_model, seed=seed, key_idx=key_idx)

        ## TODO: save hist
        print("+ save history")
        # SAVE HISTORY
        save_history(training_model, history, seed, key_idx, att)

        # add file path to list of trained models
        models[(seed, key_idx)] = get_file_path(training_model, MODEL_CONST, seed, key_idx) # TODO: models can be removed, get_file_path() is better at getting model instance
        # TODO: THE FOLLOWING 4 LINES WERE REPEATED 4 TIMES
        ## calculate test accuracy, you'll be saving them all at the end
        accuracies[(seed, key_idx)] = calc_tst_acc(data_loader, seed=seed, key_idx=key_idx)

        ## calculate ADVANTAGE
        advantages[(seed, key_idx)] = calc_advantage(accuracies.get((seed, key_idx)))


print()
print("+ Training complete")

# Save all test accuracies and advantages
print("+ Saving dictionary with all test accuracies and test advantages of all seeds (and keys if those exist)")
save_file(training_model, accuracies, case=TST_ACC_CONST)
save_file(training_model, advantages, case=TST_ADV_CONST)



# TODO: replace calculation of advantage with loading of it
display_results(models, accuracies, advantages, training_model, DB_TYPE = TYPE_ASCAD)
# Out:
# + Commense training (takes about 20 seconds per epoch)
# + Commense loading data
# ++ Loading schoolbook on m4sc data
# ++ Parse m4sc data
# ++ Finished parsing m4sc data
# ++ Normalizing traces of m4sc
# ++ Organizing traces
# ++ Data dimestions are:  (10000, 7000)
# + sample 0 traces
# key_idx=0...
# Epoch 1/200
# 90/90 [==============================] - 1s 7ms/step - loss: 1.1034 - accuracy: 0.0136 - val_loss: 1.1009 - val_accuracy: 0.0111
# Epoch 2/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1034 - accuracy: 0.0327 - val_loss: 1.1009 - val_accuracy: 0.0291
# Epoch 3/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1034 - accuracy: 0.0472 - val_loss: 1.1009 - val_accuracy: 0.0312
# Epoch 4/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1034 - accuracy: 0.0438 - val_loss: 1.1009 - val_accuracy: 0.0352
# Epoch 5/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1034 - accuracy: 0.0544 - val_loss: 1.1009 - val_accuracy: 0.0573
# Epoch 6/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1034 - accuracy: 0.0677 - val_loss: 1.1010 - val_accuracy: 0.0412
# Epoch 7/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1034 - accuracy: 0.0618 - val_loss: 1.1009 - val_accuracy: 0.0543
# Epoch 8/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1034 - accuracy: 0.0513 - val_loss: 1.1009 - val_accuracy: 0.0352
# Epoch 9/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1034 - accuracy: 0.0680 - val_loss: 1.1009 - val_accuracy: 0.0302
# Epoch 10/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1034 - accuracy: 0.0767 - val_loss: 1.1009 - val_accuracy: 0.0734
# Epoch 11/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1034 - accuracy: 0.0802 - val_loss: 1.1009 - val_accuracy: 0.0623
# Epoch 12/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1034 - accuracy: 0.0715 - val_loss: 1.1009 - val_accuracy: 0.0683
# Epoch 13/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1034 - accuracy: 0.0635 - val_loss: 1.1009 - val_accuracy: 0.0603
# Epoch 14/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1034 - accuracy: 0.0725 - val_loss: 1.1009 - val_accuracy: 0.0583
# Epoch 15/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1034 - accuracy: 0.0716 - val_loss: 1.1009 - val_accuracy: 0.0392
# Epoch 16/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1033 - accuracy: 0.0523 - val_loss: 1.1009 - val_accuracy: 0.0844
# Epoch 17/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1033 - accuracy: 0.0944 - val_loss: 1.1009 - val_accuracy: 0.0653
# Epoch 18/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1033 - accuracy: 0.0833 - val_loss: 1.1009 - val_accuracy: 0.0663
# Epoch 19/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1033 - accuracy: 0.0887 - val_loss: 1.1010 - val_accuracy: 0.0894
# Epoch 20/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1033 - accuracy: 0.0889 - val_loss: 1.1009 - val_accuracy: 0.0764
# Epoch 21/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1033 - accuracy: 0.0887 - val_loss: 1.1009 - val_accuracy: 0.0794
# Epoch 22/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1033 - accuracy: 0.0855 - val_loss: 1.1009 - val_accuracy: 0.0814
# Epoch 23/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1033 - accuracy: 0.0930 - val_loss: 1.1009 - val_accuracy: 0.0523
# Epoch 24/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1033 - accuracy: 0.0932 - val_loss: 1.1009 - val_accuracy: 0.0814
# Epoch 25/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1033 - accuracy: 0.0784 - val_loss: 1.1009 - val_accuracy: 0.0794
# Epoch 26/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1033 - accuracy: 0.0845 - val_loss: 1.1009 - val_accuracy: 0.0261
# Epoch 27/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1033 - accuracy: 0.0759 - val_loss: 1.1010 - val_accuracy: 0.0744
# Epoch 28/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1033 - accuracy: 0.0739 - val_loss: 1.1009 - val_accuracy: 0.0834
# Epoch 29/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1033 - accuracy: 0.0995 - val_loss: 1.1009 - val_accuracy: 0.0643
# Epoch 30/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1032 - accuracy: 0.0862 - val_loss: 1.1009 - val_accuracy: 0.0613
# Epoch 31/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.1032 - accuracy: 0.
200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0989 - accuracy: 0.2264 - val_loss: 1.1004 - val_accuracy: 0.1397
# Epoch 184/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0988 - accuracy: 0.2245 - val_loss: 1.1004 - val_accuracy: 0.1920
# Epoch 185/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0988 - accuracy: 0.2267 - val_loss: 1.1004 - val_accuracy: 0.1849
# Epoch 186/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0987 - accuracy: 0.2367 - val_loss: 1.1005 - val_accuracy: 0.1136
# Epoch 187/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0987 - accuracy: 0.2238 - val_loss: 1.1003 - val_accuracy: 0.1859
# Epoch 188/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0986 - accuracy: 0.2371 - val_loss: 1.1004 - val_accuracy: 0.1447
# Epoch 189/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0985 - accuracy: 0.2352 - val_loss: 1.1004 - val_accuracy: 0.1829
# Epoch 190/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0985 - accuracy: 0.2390 - val_loss: 1.1004 - val_accuracy: 0.2060
# Epoch 191/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0984 - accuracy: 0.2382 - val_loss: 1.1004 - val_accuracy: 0.1678
# Epoch 192/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0984 - accuracy: 0.2380 - val_loss: 1.1003 - val_accuracy: 0.1839
# Epoch 193/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0983 - accuracy: 0.2419 - val_loss: 1.1003 - val_accuracy: 0.1698
# Epoch 194/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0982 - accuracy: 0.2406 - val_loss: 1.1003 - val_accuracy: 0.1899
# Epoch 195/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0982 - accuracy: 0.2485 - val_loss: 1.1003 - val_accuracy: 0.2080
# Epoch 196/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0982 - accuracy: 0.2506 - val_loss: 1.1003 - val_accuracy: 0.1849
# Epoch 197/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0981 - accuracy: 0.2492 - val_loss: 1.1003 - val_accuracy: 0.1920
# Epoch 198/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0980 - accuracy: 0.2504 - val_loss: 1.1004 - val_accuracy: 0.2382
# Epoch 199/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0979 - accuracy: 0.2517 - val_loss: 1.1002 - val_accuracy: 0.1749
# Epoch 200/200
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0979 - accuracy: 0.2557 - val_loss: 1.1003 - val_accuracy: 0.2422
# + save history
# ++ Saving:  ../debugging_file_mlp3_8bits/trn_loss/trn_lss_s57935_k00.npy
# ++ Saving:  ../debugging_file_mlp3_8bits/trn_accuracy/trn_acc_s57935_k00.npy
# ++ Saving:  ../debugging_file_mlp3_8bits/graphs/trn_grph_s57935_k00.png
# ++ calculating accuracy for seed 57935 and key 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-5a09fe09d76b> in <module>
#     125         # TODO: THE FOLLOWING 4 LINES WERE REPEATED 4 TIMES
#     126         ## calculate test accuracy, you'll be saving them all at the end
# --> 127         accuracies[(seed, key_idx)] = calc_tst_acc(data_loader, seed=seed, key_idx=key_idx)
#     128
#     129         ## calculate ADVANTAGE
#
# ~/refactored/SCA-with-keras/training_modules/handling_saving_stats.py in calc_tst_acc(data_loader, seed, key_idx)
#      50 #     print("predictions cmp Y_profiling: ", (Y_attack == predictions))
#      51
# ---> 52     accuracy = sum(Y_attack == predictions)/TEST_NUM
#      53     return accuracy
#      54
#
# TypeError: 'bool' object is not iterable

# %%
# from tensorflow.python.client import device_lib
# print(device_lib.list_local_devices())
